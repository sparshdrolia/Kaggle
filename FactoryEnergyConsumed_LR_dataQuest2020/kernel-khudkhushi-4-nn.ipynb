# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.
# Out:
# /kaggle/input/dataquest2020/sample_submission.csv
# /kaggle/input/dataquest2020/energy_test.csv
# /kaggle/input/dataquest2020/energy_train.csv

# %%
data = pd.read_csv("/kaggle/input/dataquest2020/energy_train.csv")

Y = data["WattHour"]
del data["WattHour"]
del data["date"]
del data["id"]

# %%
data['degree_C1'].fillna((data['degree_C1'].mean()), inplace=True)
data['degree_C3'].fillna((data['degree_C3'].mean()), inplace=True)
data['moisture_9'].fillna((data['moisture_9'].mean()), inplace=True)

# %%
from sklearn.model_selection import train_test_split

# 75% of the data is usedfor the training of the models and the rest is used for testing
X_train, X_test, y_train, y_test = train_test_split(data, Y, test_size=0.3, random_state=2)

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
model = Sequential()

# The Input Layer :
model.add(Dense(128, kernel_initializer='normal',input_dim = X_train.shape[1], activation='relu'))

# The Hidden Layers :
model.add(Dense(256, kernel_initializer='normal',activation='relu'))
model.add(Dense(256, kernel_initializer='normal',activation='relu'))
model.add(Dense(256, kernel_initializer='normal',activation='relu'))

# The Output Layer :
model.add(Dense(1, kernel_initializer='normal',activation='linear'))

# Compile the network :
model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mean_absolute_error'])
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_31 (Dense)             (None, 128)               3584
# _________________________________________________________________
# dense_32 (Dense)             (None, 256)               33024
# _________________________________________________________________
# dense_33 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_34 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_35 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 168,449
# Trainable params: 168,449
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train, y_train, epochs=500, batch_size=32, validation_split = 0.2)
# Out:
# Train on 8400 samples, validate on 2100 samples
# Epoch 1/500
# 8400/8400 [==============================] - 1s 168us/step - loss: 52.9820 - mean_absolute_error: 52.9820 - val_loss: 56.2226 - val_mean_absolute_error: 56.2226
# Epoch 2/500
# 8400/8400 [==============================] - 1s 140us/step - loss: 50.7084 - mean_absolute_error: 50.7084 - val_loss: 47.8196 - val_mean_absolute_error: 47.8196
# Epoch 3/500
# 8400/8400 [==============================] - 1s 157us/step - loss: 50.1594 - mean_absolute_error: 50.1593 - val_loss: 47.6320 - val_mean_absolute_error: 47.6320
# Epoch 4/500
# 8400/8400 [==============================] - 1s 149us/step - loss: 49.9725 - mean_absolute_error: 49.9725 - val_loss: 47.7394 - val_mean_absolute_error: 47.7394
# Epoch 5/500
# 8400/8400 [==============================] - 1s 166us/step - loss: 49.8329 - mean_absolute_error: 49.8330 - val_loss: 47.2176 - val_mean_absolute_error: 47.2176
# Epoch 6/500
# 8400/8400 [==============================] - 1s 149us/step - loss: 49.8493 - mean_absolute_error: 49.8493 - val_loss: 47.1212 - val_mean_absolute_error: 47.1212
# Epoch 7/500
# 8400/8400 [==============================] - 1s 146us/step - loss: 49.5432 - mean_absolute_error: 49.5432 - val_loss: 47.4671 - val_mean_absolute_error: 47.4671
# Epoch 8/500
# 8400/8400 [==============================] - 1s 141us/step - loss: 49.6911 - mean_absolute_error: 49.6911 - val_loss: 47.1421 - val_mean_absolute_error: 47.1421
# Epoch 9/500
# 8400/8400 [==============================] - 1s 144us/step - loss: 49.3120 - mean_absolute_error: 49.3120 - val_loss: 46.9757 - val_mean_absolute_error: 46.9757
# Epoch 10/500
# 8400/8400 [==============================] - 1s 141us/step - loss: 49.3134 - mean_absolute_error: 49.3134 - val_loss: 46.6173 - val_mean_absolute_error: 46.6173
# Epoch 11/500
# 8400/8400 [==============================] - 1s 142us/step - loss: 49.1039 - mean_absolute_error: 49.1039 - val_loss: 49.9007 - val_mean_absolute_error: 49.9007
# Epoch 12/500
# 8400/8400 [==============================] - 1s 161us/step - loss: 49.1166 - mean_absolute_error: 49.1166 - val_loss: 47.2628 - val_mean_absolute_error: 47.2628
# Epoch 13/500
# 8400/8400 [==============================] - 1s 144us/step - loss: 49.2860 - mean_absolute_error: 49.2860 - val_loss: 47.1164 - val_mean_absolute_error: 47.1164
# Epoch 14/500
# 8400/8400 [==============================] - 1s 150us/step - loss: 48.6804 - mean_absolute_error: 48.6804 - val_loss: 46.8137 - val_mean_absolute_error: 46.8137
# Epoch 15/500
# 8400/8400 [==============================] - 1s 163us/step - loss: 48.6459 - mean_absolute_error: 48.6459 - val_loss: 45.6891 - val_mean_absolute_error: 45.6891
# Epoch 16/500
# 8400/8400 [==============================] - 2s 201us/step - loss: 48.5957 - mean_absolute_error: 48.5957 - val_loss: 48.5168 - val_mean_absolute_error: 48.5168
# Epoch 17/500
# 8400/8400 [==============================] - 1s 152us/step - loss: 48.2806 - mean_absolute_error: 48.2806 - val_loss: 45.7423 - val_mean_absolute_error: 45.7423
# Epoch 18/500
# 8400/8400 [==============================] - 1s 161us/step - loss: 48.1985 - mean_absolute_error: 48.1985 - val_loss: 45.7073 - val_mean_absolute_error: 45.7073
# Epoch 19/500
# 8400/8400 [==============================] - 1s 158us/step - loss: 48.0715 - mean_absolute_error: 48.0715 - val_loss: 49.0177 - val_mean_absolute_error: 49.0177
# Epoch 20/500
# 8400/8400 [==============================] - 1s 171us/step - loss: 48.0035 - mean_absolute_error: 48.0035 - val_loss: 45.1604 - val_mean_absolute_error: 45.1604
# Epoch 21/500
# 8400/8400 [==============================] - 1s 157us/step - loss: 47.9933 - mean_absolute_error: 47.9933 - val_loss: 45.1388 - val_mean_absolute_error: 45.1388
# Epoch 22/500
# 8400/8400 [==============================] - 1s 158us/step - loss: 47.9874 - mean_absolute_error: 47.9874 - val_loss: 45.1763 - val_mean_absolute_error: 45.1763
# Epoch 23/500
# 8400/8400 [==============================] - 1s 153us/step - loss: 47.8275 - mean_absolute_error: 47.8275 - val_loss: 45.1991 - val_mean_absolute_error: 45.1991
# Epoch 24/500
# 8400/8400 [==============================] - 1s 146us/step - loss: 47.8179 - mean_absolute_error: 47.8179 - val_loss: 47.2423 - val_mean_absolute_error: 47.2423
# Epoch 25/500
# 8400/8400 [==============================] - 1s 140us/step - loss: 47.6325 - mean_absolute_error: 47.6325 - val_loss: 46.2021 - val_mean_absolute_error: 46.2021
# Epoch 26/500
# 8400/8400 [==============================] - 1s 138us/step - loss: 47.7777 - mean_absolute_error: 47.7777 - val_loss: 48.3286 - val_mean_absolute_error: 48.3286
# Epoch 27/500
# 8400/8400 [==============================] - 1s 137us/step - loss: 47.7693 - mean_absolute_error: 47.7693 - val_loss: 44.9556 - val_mean_absolute_error: 44.9556
# Epoch 28/500
# 8400/8400 [==============================] - 1s 141us/step - loss: 48.0045 - mean_absolute_error: 48.0045 - val_loss: 45.4792 - val_mean_absolute_error: 45.4792
# Epoch 29/500
# 8400/8400 [==============================] - 1s 168us/step - loss: 47.5908 - mean_absolute_error: 47.5908 - val_loss: 44.8614 - val_mean_absolute_error: 44.8614
# Epoch 30/500
# 8400/8400 [==============================] - 1s 164us/step - loss: 47.7478 - mean_absolute_error: 47.7478 - val_loss: 46.1517 - val_mean_absolute_error: 46.1518
# Epoch 31/500
# 8400/8400 [==============================] - 1s 138us/step - loss: 47.5470 - mean_absolute_error: 47.5470 - val_loss: 45.1727 - val_mean_absolute_error: 45.1727
# Epoch 32/500
# 8400/8400 [==============================] - 1s 142us/step - loss: 47.2424 - mean_absolute_error: 47.2424 - val_loss: 47.7462 - val_mean_absolute_error: 47.7462
# Epoch 33/500
# 8400/8400 [==============================] - 1s 139us/step - loss: 47.2476 - mean_absolute_error: 47.2476 - val_loss: 45.3387 - val_mean_absolute_error: 45.3388
# Epoch 34/500
# 8400/8400 [==============================] - 1s 139us/step - loss: 47.1942 - mean_absolute_error: 47.1942 - val_loss: 44.5843 - val_mean_absolute_error: 44.5843
# Epoch 35/500
# 8400/8400 [==============================] - 1s 139us/step - loss: 47.2092 - mean_absolute_error: 47.2092 - val_loss: 45.3786 - val_mean_absolute_error: 45.3786
# Epoch 36/500
# 8400/8400 [==============================] - 1s 136us/step - loss: 47.4612 - mean_absolute_error: 47.4612 - val_loss: 45.6717 - val_mean_absolute_error: 45.6717
# Epoch 37/500
# 8400/8400 [==============================] - 1s 139us/step - loss: 47.3583 - mean_absolute_error: 47.3583 - val_loss: 44.8896 - val_mean_absolute_error: 44.8896
# Epoch 38/500
# 8400/8400 [==============================] - 1s 167us/step - loss: 47.3506 - mean_absolute_error: 47.3506 - val_loss: 45.8241 - val_mean_absolute_error: 45.8241
# Epoch 39/500
# 8400/8400 [==============================] - 1s 144us/step - loss: 47.2182 - mean_absolute_error: 47.2182 - val_loss: 44.5432 - val_mean_absolute_error: 44.5433
# Epoch 40/500
# 8400/8400 [==============================] - 1s 140us/step - loss: 47.3837 - mean_absolute_error: 47.3837 - val_loss: 44.4186 - val_mean_absolute_error: 44.4186
# Epoch 41/500
# 8400/8400 [==============================] - 1s 137us/step - loss: 47.6638 - mean_absolute_error: 47.6638 - val_loss: 44.2707 - val_mean_absolute_error: 44.2707
# Epoch 42/500
# 8400/8400 [==============================] - 1s 147us/step - loss: 47.3135 - mean_absolute_error: 47.3135 - val_loss: 44.6602 - val_mean_absolute_error: 44.6601
# Epoch 43/500
# 8400/8400 [==============================] - 1s 163us/step - loss: 47.2450 - mean_absolute_error: 47.2450 - val_loss: 44.5931 - val_mean_absolute_error: 44.5931
# Epoch 44/500
# 8400/8400 [==============================] - 1s 141us/step - loss: 47.2882 - mean_absolute_error: 47.2882 - val_loss: 46.9890 - val_mean_absolute_error: 46.9890
# Epoch 45/500
# 8400/8400 [==============================] - 1s 141us/step - loss: 47.8106 - mean_absolute_error: 47.8106 - val_loss: 44.4947 - val_mean_absolute_error: 44.4947
# Epoch 46/500
# 8400/8400 [==============================] - 1s 143us/step - loss: 46.8297 - mean_absolute_error: 46.8297 - val_loss: 44.6111 - val_mean_absolute_error: 44.6111
# Epoch 47/500
# 8400/8400 [==============================] - 2s 188us/step - loss: 47.4280 - mean_absolute_error: 47.4280 - val_loss: 45.0812 - val_mean_absolute_error: 45.0812
# Epoch 48/500
# 8400/8400 [==============================] - 1s 148us/step - loss: 46.9065 - mean_absolute_error: 46.9065 - val_loss: 47.2352 - val_mean_absolute_error: 47.2351
# Epoch 49/500
# 8400/8400 [==============================] - 1s 141us/step - loss: 46.9606 - mean_absolute_error: 46.9606 - val_loss: 45.5777 - val_mean_absolute_error: 45.5777
# Epoch 50/500
# 8400/8400 [==============================] - 1s 142us/step - loss: 47.2020 - mean_absolute_error: 47.2020 - val_loss: 44.9789 - val_mean_absolute_error: 44.9789
# Epoch 51/500
# 8400/8400 [==============================] - 1s 144us/step - loss: 46.6082 - mean_absolute_error: 46.6082 - val_loss: 43.9709 - val_mean_absolute_error: 43.9709
# Epoch 52/500
# 8400/8400 [==============================] - 1s 139us/step - loss: 46.9800 - mean_absolute_error: 46.9800 - val_loss: 44.3418 - val_mean_absolute_error: 44.3418
# Epoch 53/500
# 8400/8400 [==============================] - 1s 140us/step - loss: 47.0025 - mean_absolute_error: 47.0025 - val_loss: 44.8514 - val_mean_absolute_error: 44.8514
# Epoch 54/500
# 8400/8400 [==============================] - 1s 148us/step - loss: 46.7968 - mean_absolute_error: 46.7968 - val_loss: 44.1273 - val_mean_absolute_error: 44.1273
# Epoch 55/500
# 8400/8400 [==============================] - 1s 143us/step - loss: 46.7021 - mean_absolute_error: 46.7021 - val_loss: 47.4757 - val_mean_absolute_error: 47.4757
# Epoch 56/500
# 8400/8400 [==============================] - 2s 184us/step - loss: 46.8268 - mean_absolute_error: 46.8268 - val_loss: 45.2412 - val_mean_absolute_error: 45.2412
# Epoch 57/500
# 8400/8400 [==============================] - 1s 143us/step - loss: 46.7397 - mean_absolute_error: 46.7397 - val_loss: 48.6182 - val_mean_absolute_error: 48.6182
# Epoch 58/500
# 8400/8400 [==============================] - 1s 143us/step - loss: 46.8681 - mean_absolute_error: 46.8681 - val_loss: 46.9701 - val_mean_absolute_error: 46.9701
# Epoch 59/500
# 8400/8400 [==============================] - 1s 141us/step - loss: 46.7046 - mean_absolute_error: 46.7046 - val_loss: 44.3182 - val_mean_absolute_error: 44.3182
# Epoch 60/500
# 8400/8400 [==============================] - 1s 142us/step - loss: 46.8902 - mean_absolute_error: 46.8902 - val_loss: 45.7301 - val_mean_absolute_error: 45.7301
# Epoch 61/500
# 8400/8400 [==============================] - 1s 141us/step - loss: 46.6096 - mean_absolute_error: 46.6096 - val_loss: 44.3986 - val_mean_absolute_error: 44.3986
# Epoch 62/500
# 8400/8400 [==============================] - 1s 150us/step - loss: 47.0511 - mean_absolute_error: 47.0511 - val_loss: 44.4617 - val_mean_absolute_error: 44.4617
# Epoch 63/500
# 8400/8400 [==============================] - 2s 189us/step - loss: 46.6294 - mean_absolute_error: 46.6294 - val_loss: 44.3617 - val_mean_absolute_error: 44.3617
# Epoch 64/500
# 8400/8400 [==============================] - 1s 159us/step - loss: 46.5499 - mean_absolute_error: 46.5499 - val_loss: 44.1730 - val_mean_absolute_error: 44.1730
# Epoch 65/500
# 8400/8400 [==============================] - 1s 143us/step - loss: 46.9658 - mean_absolute_error: 46.9658 - val_loss: 44.9571 - val_mean_absolute_error: 44.9571
# Epoch 66/500
# 8400/8400 [==============================] - 1s 175us/step - loss: 46.7942 - mean_absolute_error: 46.7942 - val_loss: 45.1857 - val_mean_absolute_error: 45.1857
# Epoch 67/500
# 8400/8400 [==============================] - 1s 152us/step - loss: 46.5415 - mean_absolute_error: 46.5414 - val_loss: 43.8736 - val_mean_absolute_error: 43.8736
# Epoch 68/500
# 8400/8400 [==============================] - 1s 144us/step - loss: 46.5064 - mean_absolute_error: 46.5063 - val_loss: 45.0738 - val_mean_absolute_error: 45.0738
# Epoch 69/500
# 8400/8400 [==============================] - 1s 150us/step - loss: 46.4404 - mean_absolute_error: 46.4404 - val_loss: 43.7327 - val_mean_absolute_error: 43.7327
# Epoch 70/500
# 8400/8400 [==============================] - 1s 155us/step - loss: 46.3165 - mean_absolute_error: 46.3165 - val_loss: 45.0798 - val_mean_absolute_error: 45.0798
# Epoch 71/500
# 6528/8400 [======================>.......] - ETA: 0s - loss: 46.6718 - mean_absolute_error: 46.6718
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-31-7313821338fe> in <module>
# ----> 1 model.fit(X_train, y_train, epochs=500, batch_size=32, validation_split = 0.2)
#
# /opt/conda/lib/python3.7/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#    1237                                         steps_per_epoch=steps_per_epoch,
#    1238                                         validation_steps=validation_steps,
# -> 1239                                         validation_freq=validation_freq)
#    1240
#    1241     def evaluate(self,
#
# /opt/conda/lib/python3.7/site-packages/keras/engine/training_arrays.py in fit_loop(model, fit_function, fit_inputs, out_labels, batch_size, epochs, verbose, callbacks, val_function, val_inputs, shuffle, initial_epoch, steps_per_epoch, validation_steps, validation_freq)
#     194                     ins_batch[i] = ins_batch[i].toarray()
#     195
# --> 196                 outs = fit_function(ins_batch)
#     197                 outs = to_list(outs)
#     198                 for l, o in zip(out_labels, outs):
#
# /opt/conda/lib/python3.7/site-packages/tensorflow_core/python/keras/backend.py in __call__(self, inputs)
#    3733     return nest.pack_sequence_as(
#    3734         self._outputs_structure,
# -> 3735         [x._numpy() for x in outputs],  # pylint: disable=protected-access
#    3736         expand_composites=True)
#    3737
#
# /opt/conda/lib/python3.7/site-packages/tensorflow_core/python/keras/backend.py in <listcomp>(.0)
#    3733     return nest.pack_sequence_as(
#    3734         self._outputs_structure,
# -> 3735         [x._numpy() for x in outputs],  # pylint: disable=protected-access
#    3736         expand_composites=True)
#    3737
#
# /opt/conda/lib/python3.7/site-packages/tensorflow_core/python/framework/ops.py in _numpy(self)
#     906     # pylint: disable=protected-access
#     907     try:
# --> 908       return self._numpy_internal()
#     909     except core._NotOkStatusException as e:
#     910       six.raise_from(core._status_to_exception(e.code, e.message), None)
#
# KeyboardInterrupt:
